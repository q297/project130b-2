# %%
from pathlib import Path
import pandas as pd
PARQUET_FILE = Path("/workspaces/super-duper-dollop/data/processed/dataset.parquet")
dataset = pd.read_parquet(PARQUET_FILE).dropna().reset_index(drop=True).drop(0)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1632 entries, 1 to 1632
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Path    1632 non-null   object
#  1   Label   1632 non-null   bool
# dtypes: bool(1), object(1)
# memory usage: 14.5+ KB

# %%
print(dataset['Label'].value_counts())
print(dataset['Label'].value_counts(normalize=True))
# Out:
# Label
# True     1025
# False     607
# Name: count, dtype: int64
# Label
# True     0.628064
# False    0.371936
# Name: proportion, dtype: float64
